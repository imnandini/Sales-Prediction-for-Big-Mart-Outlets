# %%
#import required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#loading data
train_data = pd.read_csv("train_v9rqX0R.csv")
test_data = pd.read_csv("test_AbJTz2l.csv")

# %% [markdown]
# ### Explotary Data Analysis:

# %%
# To get the top 5 records of train
train_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# To get the top 5 records of test
test_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
train_data.describe(include ='all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# unique                     16          NaN                10
# top     Fruits and Vegetables          NaN            OUT027
# freq                     1232          NaN               935
# mean                      NaN   140.992782               NaN
# std                       NaN    62.275067               NaN
# min                       NaN    31.290000               NaN
# 25%                       NaN    93.826500               NaN
# 50%                       NaN   143.012800               NaN
# 75%                       NaN   185.643700               NaN
# max                       NaN   266.888400               NaN
#
#         Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# count                 8523.000000        6113                 8523
# unique                        NaN           3                    3
# top                           NaN      Medium               Tier 3
# freq                          NaN        2793                 3350
# mean                  1997.831867         NaN                  NaN
# std                      8.371760         NaN                  NaN
# min                   1985.000000         NaN                  NaN
# 25%                   1987.000000         NaN                  NaN
# 50%                   1999.000000         NaN                  NaN
# 75%                   2004.000000         NaN                  NaN
# max                   2009.000000         NaN                  NaN
#
#               Outlet_Type  Item_Outlet_Sales
# count                8523        8523.000000
# unique                  4                NaN
# top     Supermarket Type1                NaN
# freq                 5577                NaN
# mean                  NaN        2181.288914
# std                   NaN        1706.499616
# min                   NaN          33.290000
# 25%                   NaN         834.247400
# 50%                   NaN        1794.331000
# 75%                   NaN        3101.296400
# max                   NaN       13086.964800

# %%
# To get the dimensions of train data
train_data.shape
# Out:
# (8523, 12)

# %%
# To get the dimensions of test data
test_data.shape
# Out:
# (5681, 11)

# %%
#removing duplicates from train data
train_data.drop_duplicates(keep='first', inplace=True)
train_data.shape
# Out:
# (8523, 12)

# %%
#removing duplicates from test data
test_data.drop_duplicates(keep='first', inplace=True)
test_data.shape
# Out:
# (5681, 11)

# %%
#checking data types of train data
train_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#checking data types of test data
test_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
#checking any unique values are there in train data
train_data.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
#checking sum of null values from train data
train_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#checking sum of null values from test data
test_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
cols = train_data.columns
cols
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#histogram
sns.distplot(train_data['Item_Outlet_Sales']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data=train_data, x=train_data["Outlet_Size"])

# %%
sns.countplot(data=train_data, x=train_data["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.countplot(data=train_data, x=train_data["Item_Type"])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
sns.histplot(x = "Item_MRP" , data = train_data)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Count'>

# %%
train_data.hist(color ='blue', figsize = (15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# creating mask
mask = np.triu(np.ones_like(train_data.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(train_data.corr(), cmap="YlGnBu", annot=True, mask=mask)
 
# displaying heatmap
plt.show()

# %%
test_data1 = test_data.copy()

# %%
xtr = train_data.drop(["Item_Identifier","Outlet_Identifier","Item_Outlet_Sales"],axis=1)
xte = test_data.drop(["Item_Identifier","Outlet_Identifier"],axis=1)

# %%
# Histogram to check the distribution of all the numerical columns
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
xtr.hist(ax = ax, bins = 15)
plt.show()
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
# Out:
# C:\Users\Nandu\AppData\Local\Temp\ipykernel_26484\1356236228.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   xtr.hist(ax = ax, bins = 15)

# %%
# Scatterplot to check the relation between each pair of numerical columns
pd.plotting.scatter_matrix(xtr, figsize=(16, 16), diagonal='kde')
plt.show()

# %%
ytr = train_data[["Item_Outlet_Sales"]]

# %%
cat_cols = [col for col in xtr.columns if xtr.dtypes[col]=="object"]
cat_cols
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
num_cols = [col for col in xtr.columns if xtr.dtypes[col] !="object"]
num_cols
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']

# %%
xtr_cat = xtr[cat_cols]
xtr_num = xtr[num_cols]
xte_cat = xte[cat_cols]
xte_num = xte[num_cols]

# %% [markdown]
# ### Null value imputation

# %%
from sklearn.impute import SimpleImputer
cat_impu=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
num_impu=SimpleImputer(missing_values=np.nan,strategy ="median")
xtr_cat=pd.DataFrame(cat_impu.fit_transform(xtr_cat),columns=cat_cols)
xtr_num=pd.DataFrame(num_impu.fit_transform(xtr_num),columns=num_cols)
xte_cat=pd.DataFrame(cat_impu.fit_transform(xte_cat),columns=cat_cols)
xte_num=pd.DataFrame(num_impu.fit_transform(xte_num),columns=num_cols)

# %%
# Function to convert all object columns to categorical
xtr_cat[cat_cols]=xtr_cat[cat_cols].astype("category")
xte_cat[cat_cols]=xte_cat[cat_cols].astype("category")

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for col in cat_cols:
    xtr_cat[col]=encoder.fit_transform(xtr_cat[col])
    xte_cat[col]=encoder.fit_transform(xte_cat[col])

# %%
xtr_cat.head()
# Out:
#    Item_Fat_Content  Item_Type  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                 1          4            1                     0            1
# 1                 2         14            1                     2            2
# 2                 1         10            1                     0            1
# 3                 2          6            1                     2            0
# 4                 1          9            0                     2            1

# %%
train_data.shape
# Out:
# (8523, 12)

# %%
xtr=pd.concat([xtr_num,xtr_cat],axis=1)

# %%
xte=pd.concat([xte_num,xte_cat],axis=1)

# %%
columnsxtr = xtr.columns
columnsxtr
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Fat_Content', 'Item_Type',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
columnsxte = xte.columns
columnsxte
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Fat_Content', 'Item_Type',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
scale.fit(xtr)
# Out:
# MinMaxScaler()

# %%
xtr = pd.DataFrame(scale.transform(xtr),columns=columnsxtr)

# %%
xtr.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Fat_Content             0
# Item_Type                    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
xte.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Fat_Content             0
# Item_Type                    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
xte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                5681 non-null   float64
#  1   Item_Visibility            5681 non-null   float64
#  2   Item_MRP                   5681 non-null   float64
#  3   Outlet_Establishment_Year  5681 non-null   float64
#  4   Item_Fat_Content           5681 non-null   int32
#  5   Item_Type                  5681 non-null   int32
#  6   Outlet_Size                5681 non-null   int32
#  7   Outlet_Location_Type       5681 non-null   int32
#  8   Outlet_Type                5681 non-null   int32
# dtypes: float64(4), int32(5)
# memory usage: 288.6 KB

# %%
xte = pd.DataFrame(scale.transform(xte),columns=columnsxte)

# %%
xte.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0     0.964275         0.023036  0.325012                   0.583333
# 1     0.222983         0.117018  0.237819                   0.916667
# 2     0.598095         0.303221  0.893316                   0.541667
# 3     0.164335         0.046860  0.525233                   0.916667
# 4     0.473057         0.361153  0.861381                   0.000000
#
#    Item_Fat_Content  Item_Type  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0              0.25   0.866667          0.5                   0.0     0.333333
# 1              1.00   0.266667          0.5                   0.5     0.333333
# 2              0.25   0.733333          0.5                   1.0     0.000000
# 3              0.25   0.866667          0.5                   0.5     0.333333
# 4              0.50   0.266667          0.5                   1.0     1.000000

# %%
# creating mask
mask = np.triu(np.ones_like(xte.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(xte.corr(), cmap="YlGnBu", annot=True, mask=mask)
 
# displaying heatmap
plt.show()

# %%
import matplotlib.pyplot as plt
for col in xtr.columns:
    print("for",col)
    plt.scatter(xtr[col],ytr)
    plt.show()
# Out:
# for Item_Weight
# for Item_Visibility
# for Item_MRP
# for Outlet_Establishment_Year
# for Item_Fat_Content
# for Item_Type
# for Outlet_Size
# for Outlet_Location_Type
# for Outlet_Type

# %%
from scipy.stats import pearsonr
for col in xtr.columns:
    print("correlation with Customer_Lifetime_Value and", col)
    print(pearsonr(xtr[col],ytr["Item_Outlet_Sales"]))
    print("-------------------------------")
# Out:
# correlation with Customer_Lifetime_Value and Item_Weight
# PearsonRResult(statistic=0.009692875826630969, pvalue=0.3709277014534397)
# -------------------------------
# correlation with Customer_Lifetime_Value and Item_Visibility
# PearsonRResult(statistic=-0.12862461222077023, pvalue=9.041287180038789e-33)
# -------------------------------
# correlation with Customer_Lifetime_Value and Item_MRP
# PearsonRResult(statistic=0.5675744466569193, pvalue=0.0)
# -------------------------------
# correlation with Customer_Lifetime_Value and Outlet_Establishment_Year
# PearsonRResult(statistic=-0.04913497044082157, pvalue=5.6730821083876335e-06)
# -------------------------------
# correlation with Customer_Lifetime_Value and Item_Fat_Content
# PearsonRResult(statistic=0.00980000085823146, pvalue=0.36566353794397755)
# -------------------------------
# correlation with Customer_Lifetime_Value and Item_Type
# PearsonRResult(statistic=0.017047669665570458, pvalue=0.11555080800594694)
# -------------------------------
# correlation with Customer_Lifetime_Value and Outlet_Size
# PearsonRResult(statistic=-0.0861821954424413, pvalue=1.5865778240549604e-15)
# -------------------------------
# correlation with Customer_Lifetime_Value and Outlet_Location_Type
# PearsonRResult(statistic=0.08936674677409288, pvalue=1.3890238348303886e-16)
# -------------------------------
# correlation with Customer_Lifetime_Value and Outlet_Type
# PearsonRResult(statistic=0.40152249995360034, pvalue=0.0)
# -------------------------------

# %% [markdown]
# ### Splitting our data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(xtr,ytr,test_size=0.25,random_state=142)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6392, 9)
# (2131, 9)
# (6392, 1)
# (2131, 1)

# %% [markdown]
# ### Model Building

# %%
from sklearn.metrics import precision_score,confusion_matrix,mean_absolute_error,mean_squared_error,classification_report
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
train_pred=reg.predict(x_train)
test_pred = reg.predict(x_test)
print('RMSE LinearRegression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE LinearRegression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE LinearRegression on train :  1194.8723847376668
# RMSE LinearRegression on test :  1204.2920728727047

# %%
from sklearn.linear_model import Ridge, Lasso
#Ridge Regression Model
ridgeReg = Ridge(alpha=10)

ridgeReg.fit(x_train,y_train)

train_pred=ridgeReg.predict(x_train)
test_pred = ridgeReg.predict(x_test)
print('Ridge Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('Ridge Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# Ridge Regression on train :  1195.294257872625
# Ridge Regression on test :  1204.3210259984357

# %%
#Lasso regression model
lasso = Lasso(alpha = 10)
lasso.fit(x_train,y_train)
train_pred=lasso.predict(x_train)
test_pred = lasso.predict(x_test)
print('lasso Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('lasso Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# lasso Regression on train :  1200.2196556708618
# lasso Regression on test :  1208.0590476981417

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(random_state=3,max_depth=9,min_samples_leaf=3)
model_RFR.fit(x_train, y_train)
train_pred=model_RFR.predict(x_train)
test_pred = model_RFR.predict(x_test)
print('RMSE RandomForestRegressor on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE RandomForestRegressor on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# C:\Users\Nandu\AppData\Local\Temp\ipykernel_26484\1519345811.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_RFR.fit(x_train, y_train)
# RMSE RandomForestRegressor on train :  958.8472803174751
# RMSE RandomForestRegressor on test :  1095.7469156301972

# %% [markdown]
# From above models ,conclude that using RandomForestRegressor fits the data correctly so using RandomForestRegressor for the test data

# %%
#RandomSearchCV designed to find the best parameters to improve our model
from sklearn.model_selection import RandomizedSearchCV
rf_grid = RandomForestRegressor(random_state=4)
rf_param_grid = {"n_estimators" : [2,4,6,8,10,12,14,16,20,25],
                 "max_depth" : [5,7,9,11,13,15],
                 "min_samples_leaf" : [2,3,5,7,10]}
rf2=RandomizedSearchCV(rf_grid,rf_param_grid,cv=10,n_jobs=-1,n_iter=3000)
rf2.fit(x_train,y_train)
train_pred=rf2.predict(x_train)
test_pred = rf2.predict(x_test)
print('RMSE RandomizedSearchCV on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE RandomizedSearchCV on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 300 is smaller than n_iter=3000. Running 300 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# RMSE RandomizedSearchCV on train :  1063.7667949415988
# RMSE RandomizedSearchCV on test :  1093.7568974010273

# %% [markdown]
# ### Predictions

# %%
Target = pd.DataFrame(model_RFR.predict(xte),columns=['Item_Outlet_Sales'])

# %%
Item_Identifier=pd.DataFrame(test_data1.Item_Identifier)
Outlet_Identifier=pd.DataFrame(test_data1.Outlet_Identifier)

# %%
pred=pd.concat([Item_Identifier,Outlet_Identifier,Target],axis=1)

# %%
pred.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049        1671.393899
# 1           FDW14            OUT017        1285.017259
# 2           NCN55            OUT010         645.279696
# 3           FDQ58            OUT017        2352.720116
# 4           FDY38            OUT027        5832.579967

# %%
pred.to_csv('Submissionrfr.csv',index=False)

# %%
submission=pd.read_csv("Submissionrfr.csv")

# %%
submission.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049        1671.393899
# 1           FDW14            OUT017        1285.017259
# 2           NCN55            OUT010         645.279696
# 3           FDQ58            OUT017        2352.720116
# 4           FDY38            OUT027        5832.579967
